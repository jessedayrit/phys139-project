# %%
from keras.src.callbacks import EarlyStopping

from database_io import *
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.utils import Sequence
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from scipy import optimize as optim


print(np.__version__)
# Out:
# 1.26.4

# %%
# path of databases (must exist)
db_path = "db/"

# filenames of databases (this must be sqlite3 databases)
train_fname = "surf17BigBoy_train.db"
validation_fname = "surf17_validation.db"
test_fname = "surf17_test.db"

dim_syndr = 8
dim_fsyndr = 4
n_steps_net1 = 20
n_steps_net2 = 3

data = DatabaseIO(dim_syndr, dim_fsyndr, n_steps_net1, n_steps_net2)

# %%
try:
    data.close_databases()
except:
    pass
data.load_data(db_path + train_fname, db_path + validation_fname, db_path + test_fname)



batch_size = 64
n_batches_train = 1000
n_batches_validation = 100



class DecoderSequence(Sequence):
    def __init__(self, data, batch_size, n_batches, data_type):
        self.data = data
        self.batch_size = batch_size
        self.n_batches = n_batches
        self.data_type = data_type
        self.on_epoch_end()

    def __len__(self):
        return self.n_batches

    def __getitem__(self, idx):
        # return the idx-th batch captured at epoch start
        return self.epoch_batches[idx]

    def on_epoch_end(self):
        """Called automatically by Keras at the end of each epoch."""
        gen = self.data.gen_batches(
            self.batch_size,
            self.n_batches,
            data_type=self.data_type
        )

        self.epoch_batches = []
        for _ in range(self.n_batches):
            batch_x1, batch_x2, batch_fx, batch_l1, batch_l2, batch_y = next(gen)

            # Wrap into Keras multi-input format
            inputs = (batch_x1, batch_x2, batch_fx) #, batch_l1, batch_l2)
            outputs = batch_y
            self.epoch_batches.append((inputs, outputs))

train_seq = DecoderSequence(
    data,
    batch_size=batch_size,
    n_batches=n_batches_train,
    data_type='training'
)

val_seq = DecoderSequence(
    data,
    batch_size=batch_size,
    n_batches=n_batches_validation,
    data_type='validation'
)
# Out:
# loaded databases and checked exclusiveness training, validation, and test keys
# N_training=1000000, N_validaiton=10000, N_test=50000.

# %%
# DEFINING THE MODEL
x1 = Input(shape=(None, dim_syndr), name="x1_full")
x2 = Input(shape=(n_steps_net2, dim_syndr), name="x2_recent")
fx = Input(shape=(dim_fsyndr,), name="final_increment")

x1_masked = layers.Masking(mask_value=0.0)(x1)

dropout_rate = 0.2
layer_width = 64

# Network 1 (full syndrome history)
h1 = layers.LSTM(layer_width, activation="relu", return_sequences=True, kernel_regularizer=keras.regularizers.l2(1e-5))(x1_masked)
h1 = layers.Dropout(dropout_rate)(h1)
h1 = layers.LSTM(layer_width, activation="relu", kernel_regularizer=keras.regularizers.l2(1e-5))(h1)
h1 = layers.Dropout(dropout_rate)(h1)
p1 = layers.Dense(layer_width, activation="relu", name="p1", kernel_regularizer=keras.regularizers.l2(1e-5))(h1)
p1 = layers.Dropout(dropout_rate)(p1)
p1 = layers.Dense(1, activation="sigmoid", kernel_regularizer=keras.regularizers.l2(1e-5), name="p1_prob")(p1)


# Network 2 (recent syndrome + final increment)
h2 = layers.LSTM(layer_width, activation="relu", kernel_regularizer=keras.regularizers.l2(1e-5), return_sequences=True)(x2)
h2 = layers.Dropout(dropout_rate)(h2)
h2 = layers.LSTM(layer_width, activation="relu", kernel_regularizer=keras.regularizers.l2(1e-5))(h2)
h2 = layers.Dropout(dropout_rate)(h2)

p2 = layers.Concatenate()([h2, fx])
p2 = layers.Dense(layer_width, activation="relu", name="p2", kernel_regularizer=keras.regularizers.l2(1e-5))(p2)
p2 = layers.Dropout(dropout_rate)(p2)
p2 = layers.Dense(1, activation="sigmoid", name="p2_prob", kernel_regularizer=keras.regularizers.l2(1e-5))(p2)


# Final combination p = probabilistic sum
p_final = layers.Lambda(lambda x: x[0]*(1-x[1]) + x[1]*(1-x[0]))([p1, p2]) # XOR Gate

model = Model(inputs=[x1, x2, fx], outputs=p_final)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ x1_full             │ (None, None, 8)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, None, 8)   │          0 │ x1_full[0][0]     │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ x2_recent           │ (None, 3, 8)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking (Masking)   │ (None, None, 8)   │          0 │ x1_full[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any (Any)           │ (None, None)      │          0 │ not_equal[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 3, 64)     │     18,688 │ x2_recent[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, None, 64)  │     18,688 │ masking[0][0],    │
# │                     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 3, 64)     │          0 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, None, 64)  │          0 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 64)        │     33,024 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 64)        │     33,024 │ dropout[0][0],    │
# │                     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 64)        │          0 │ lstm_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_increment     │ (None, 4)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ lstm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 68)        │          0 │ dropout_4[0][0],  │
# │ (Concatenate)       │                   │            │ final_increment[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p1 (Dense)          │ (None, 64)        │      4,160 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p2 (Dense)          │ (None, 64)        │      4,416 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64)        │          0 │ p1[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64)        │          0 │ p2[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p1_prob (Dense)     │ (None, 1)         │         65 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p2_prob (Dense)     │ (None, 1)         │         65 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 1)         │          0 │ p1_prob[0][0],    │
# │                     │                   │            │ p2_prob[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 112,130 (438.01 KB)
#  Trainable params: 112,130 (438.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# COMPILING AND TRAINING THE MODEL
model.compile(
    loss="binary_crossentropy",
    optimizer=tf.keras.optimizers.Adam(1e-3),
    metrics=["accuracy"]
)

num_epochs = 1000

checkpoint = ModelCheckpoint(
    'best_model.keras',        # file path to save the model
    monitor='val_accuracy',    # metric to monitor
    verbose=1,                 # prints message when saving
    save_best_only=True,       # only save if improved
    mode='max'                 # 'min' for loss, 'max' for accuracy
)

early_stop = EarlyStopping(
    monitor='val_accuracy',        # use validation loss to monitor
    patience=50,               # stop after n epochs with no improvement
    min_delta=1e-4,            # threshold for minimum change over epochs -> "no imporovement"
    restore_best_weights=True, # keeps weights from the best epoch
    verbose=1
)


results = model.fit(
    train_seq,
    steps_per_epoch=n_batches_train,
    epochs=num_epochs,
    verbose=1,
    validation_data=val_seq,
    validation_steps=n_batches_validation,
    callbacks=[checkpoint, early_stop]
)
# Out:
# /opt/anaconda3/envs/phys139-project/lib/python3.13/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6110 - loss: 0.6135
# Epoch 1: val_accuracy improved from None to 0.50219, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.6774 - loss: 0.5230 - val_accuracy: 0.5022 - val_loss: 0.7031
# Epoch 2/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8423 - loss: 0.3363
# Epoch 2: val_accuracy improved from 0.50219 to 0.54125, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.8605 - loss: 0.3166 - val_accuracy: 0.5412 - val_loss: 0.6980
# Epoch 3/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8872 - loss: 0.2701
# Epoch 3: val_accuracy improved from 0.54125 to 0.55969, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.8901 - loss: 0.2583 - val_accuracy: 0.5597 - val_loss: 0.6858
# Epoch 4/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8964 - loss: 0.2363
# Epoch 4: val_accuracy improved from 0.55969 to 0.59094, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.8982 - loss: 0.2351 - val_accuracy: 0.5909 - val_loss: 0.6588
# Epoch 5/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9057 - loss: 0.2205
# Epoch 5: val_accuracy improved from 0.59094 to 0.60375, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9056 - loss: 0.2198 - val_accuracy: 0.6037 - val_loss: 0.6589
# Epoch 6/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9107 - loss: 0.2069
# Epoch 6: val_accuracy improved from 0.60375 to 0.61406, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9125 - loss: 0.2040 - val_accuracy: 0.6141 - val_loss: 0.6966
# Epoch 7/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9132 - loss: 0.2037
# Epoch 7: val_accuracy did not improve from 0.61406
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9142 - loss: 0.2008 - val_accuracy: 0.6062 - val_loss: 0.6366
# Epoch 8/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9167 - loss: 0.1933
# Epoch 8: val_accuracy improved from 0.61406 to 0.64375, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9167 - loss: 0.1940 - val_accuracy: 0.6438 - val_loss: 0.6213
# Epoch 9/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9191 - loss: 0.1917
# Epoch 9: val_accuracy did not improve from 0.64375
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9197 - loss: 0.1902 - val_accuracy: 0.6298 - val_loss: 0.6129
# Epoch 10/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9201 - loss: 0.1897
# Epoch 10: val_accuracy did not improve from 0.64375
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9210 - loss: 0.1875 - val_accuracy: 0.6364 - val_loss: 0.6131
# Epoch 11/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9237 - loss: 0.1815
# Epoch 11: val_accuracy improved from 0.64375 to 0.66594, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9242 - loss: 0.1805 - val_accuracy: 0.6659 - val_loss: 0.6010
# Epoch 12/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9262 - loss: 0.1771
# Epoch 12: val_accuracy did not improve from 0.66594
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9269 - loss: 0.1773 - val_accuracy: 0.6405 - val_loss: 0.6109
# Epoch 13/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9278 - loss: 0.1744
# Epoch 13: val_accuracy did not improve from 0.66594
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9283 - loss: 0.1738 - val_accuracy: 0.6500 - val_loss: 0.6141
# Epoch 14/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9280 - loss: 0.1753
# Epoch 14: val_accuracy did not improve from 0.66594
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9274 - loss: 0.1759 - val_accuracy: 0.6653 - val_loss: 0.6137
# Epoch 15/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9293 - loss: 0.1724
# Epoch 15: val_accuracy did not improve from 0.66594
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9298 - loss: 0.1731 - val_accuracy: 0.6519 - val_loss: 0.6420
# Epoch 16/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9313 - loss: 0.1710
# Epoch 16: val_accuracy did not improve from 0.66594
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9323 - loss: 0.1705 - val_accuracy: 0.6259 - val_loss: 0.6118
# Epoch 17/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9328 - loss: 0.1696
# Epoch 17: val_accuracy did not improve from 0.66594
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9335 - loss: 0.1684 - val_accuracy: 0.6584 - val_loss: 0.5979
# Epoch 18/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9351 - loss: 0.1651
# Epoch 18: val_accuracy improved from 0.66594 to 0.68125, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9361 - loss: 0.1642 - val_accuracy: 0.6812 - val_loss: 0.6118
# Epoch 19/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9364 - loss: 0.1651
# Epoch 19: val_accuracy did not improve from 0.68125
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9367 - loss: 0.1652 - val_accuracy: 0.6711 - val_loss: 0.5894
# Epoch 20/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9397 - loss: 0.1596
# Epoch 20: val_accuracy did not improve from 0.68125
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9388 - loss: 0.1619 - val_accuracy: 0.6653 - val_loss: 0.5888
# Epoch 21/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9403 - loss: 0.1567
# Epoch 21: val_accuracy did not improve from 0.68125
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9401 - loss: 0.1579 - val_accuracy: 0.6791 - val_loss: 0.5714
# Epoch 22/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9451 - loss: 0.1526
# Epoch 22: val_accuracy improved from 0.68125 to 0.68641, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9428 - loss: 0.1569 - val_accuracy: 0.6864 - val_loss: 0.5901
# Epoch 23/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9411 - loss: 0.1609
# Epoch 23: val_accuracy did not improve from 0.68641
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9408 - loss: 0.1603 - val_accuracy: 0.6794 - val_loss: 0.5774
# Epoch 24/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9413 - loss: 0.1600
# Epoch 24: val_accuracy improved from 0.68641 to 0.69078, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9409 - loss: 0.1605 - val_accuracy: 0.6908 - val_loss: 0.5924
# Epoch 25/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9439 - loss: 0.1544
# Epoch 25: val_accuracy improved from 0.69078 to 0.69844, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9438 - loss: 0.1545 - val_accuracy: 0.6984 - val_loss: 0.5641
# Epoch 26/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9417 - loss: 0.1548
# Epoch 26: val_accuracy improved from 0.69844 to 0.70281, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9435 - loss: 0.1531 - val_accuracy: 0.7028 - val_loss: 0.5825
# Epoch 27/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9433 - loss: 0.1546
# Epoch 27: val_accuracy did not improve from 0.70281
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9438 - loss: 0.1545 - val_accuracy: 0.7008 - val_loss: 0.5675
# Epoch 28/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9448 - loss: 0.1542
# Epoch 28: val_accuracy did not improve from 0.70281
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9450 - loss: 0.1535 - val_accuracy: 0.6855 - val_loss: 0.5920
# Epoch 29/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9429 - loss: 0.1563
# Epoch 29: val_accuracy improved from 0.70281 to 0.71000, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9435 - loss: 0.1570 - val_accuracy: 0.7100 - val_loss: 0.5566
# Epoch 30/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9447 - loss: 0.1497
# Epoch 30: val_accuracy did not improve from 0.71000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9441 - loss: 0.1509 - val_accuracy: 0.6847 - val_loss: 0.5797
# Epoch 31/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9447 - loss: 0.1517
# Epoch 31: val_accuracy did not improve from 0.71000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9444 - loss: 0.1507 - val_accuracy: 0.6922 - val_loss: 0.5640
# Epoch 32/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9442 - loss: 0.1546
# Epoch 32: val_accuracy did not improve from 0.71000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9450 - loss: 0.1518 - val_accuracy: 0.6775 - val_loss: 0.6011
# Epoch 33/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9457 - loss: 0.1494
# Epoch 33: val_accuracy did not improve from 0.71000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9452 - loss: 0.1497 - val_accuracy: 0.7095 - val_loss: 0.5602
# Epoch 34/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9453 - loss: 0.1522
# Epoch 34: val_accuracy improved from 0.71000 to 0.71078, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9452 - loss: 0.1521 - val_accuracy: 0.7108 - val_loss: 0.5960
# Epoch 35/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9469 - loss: 0.1494
# Epoch 35: val_accuracy improved from 0.71078 to 0.71844, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9466 - loss: 0.1495 - val_accuracy: 0.7184 - val_loss: 0.5918
# Epoch 36/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9461 - loss: 0.1508
# Epoch 36: val_accuracy did not improve from 0.71844
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9464 - loss: 0.1496 - val_accuracy: 0.6984 - val_loss: 0.5603
# Epoch 37/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9440 - loss: 0.1544
# Epoch 37: val_accuracy did not improve from 0.71844
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9450 - loss: 0.1518 - val_accuracy: 0.7159 - val_loss: 0.5598
# Epoch 38/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9455 - loss: 0.1498
# Epoch 38: val_accuracy did not improve from 0.71844
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9472 - loss: 0.1476 - val_accuracy: 0.7022 - val_loss: 0.5616
# Epoch 39/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9460 - loss: 0.1506
# Epoch 39: val_accuracy did not improve from 0.71844
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9473 - loss: 0.1494 - val_accuracy: 0.7127 - val_loss: 0.5674
# Epoch 40/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9447 - loss: 0.1498
# Epoch 40: val_accuracy did not improve from 0.71844
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9451 - loss: 0.1493 - val_accuracy: 0.7184 - val_loss: 0.5401
# Epoch 41/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9469 - loss: 0.1508
# Epoch 41: val_accuracy did not improve from 0.71844
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9469 - loss: 0.1490 - val_accuracy: 0.6892 - val_loss: 0.5661
# Epoch 42/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9465 - loss: 0.1486
# Epoch 42: val_accuracy did not improve from 0.71844
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9474 - loss: 0.1471 - val_accuracy: 0.7017 - val_loss: 0.5728
# Epoch 43/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9467 - loss: 0.1511
# Epoch 43: val_accuracy improved from 0.71844 to 0.72141, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9462 - loss: 0.1497 - val_accuracy: 0.7214 - val_loss: 0.5642
# Epoch 44/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9464 - loss: 0.1509
# Epoch 44: val_accuracy did not improve from 0.72141
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9463 - loss: 0.1508 - val_accuracy: 0.7109 - val_loss: 0.5592
# Epoch 45/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9463 - loss: 0.1512
# Epoch 45: val_accuracy did not improve from 0.72141
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9478 - loss: 0.1474 - val_accuracy: 0.7188 - val_loss: 0.5992
# Epoch 46/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9477 - loss: 0.1488
# Epoch 46: val_accuracy did not improve from 0.72141
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9483 - loss: 0.1466 - val_accuracy: 0.7097 - val_loss: 0.5499
# Epoch 47/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9472 - loss: 0.1467
# Epoch 47: val_accuracy did not improve from 0.72141
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9473 - loss: 0.1475 - val_accuracy: 0.7189 - val_loss: 0.5474
# Epoch 48/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9473 - loss: 0.1494
# Epoch 48: val_accuracy did not improve from 0.72141
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9480 - loss: 0.1478 - val_accuracy: 0.7172 - val_loss: 0.5766
# Epoch 49/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9486 - loss: 0.1471
# Epoch 49: val_accuracy improved from 0.72141 to 0.72375, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9487 - loss: 0.1470 - val_accuracy: 0.7237 - val_loss: 0.5423
# Epoch 50/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9477 - loss: 0.1452
# Epoch 50: val_accuracy improved from 0.72375 to 0.72562, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9491 - loss: 0.1423 - val_accuracy: 0.7256 - val_loss: 0.5461
# Epoch 51/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9492 - loss: 0.1425
# Epoch 51: val_accuracy improved from 0.72562 to 0.73094, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9495 - loss: 0.1432 - val_accuracy: 0.7309 - val_loss: 0.5320
# Epoch 52/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9476 - loss: 0.1444
# Epoch 52: val_accuracy did not improve from 0.73094
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9470 - loss: 0.1464 - val_accuracy: 0.7281 - val_loss: 0.5255
# Epoch 53/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9491 - loss: 0.1424
# Epoch 53: val_accuracy did not improve from 0.73094
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9484 - loss: 0.1440 - val_accuracy: 0.7237 - val_loss: 0.5490
# Epoch 54/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9470 - loss: 0.1496
# Epoch 54: val_accuracy improved from 0.73094 to 0.73687, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9465 - loss: 0.1484 - val_accuracy: 0.7369 - val_loss: 0.5619
# Epoch 55/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9483 - loss: 0.1472
# Epoch 55: val_accuracy did not improve from 0.73687
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9492 - loss: 0.1433 - val_accuracy: 0.7216 - val_loss: 0.5466
# Epoch 56/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9488 - loss: 0.1425
# Epoch 56: val_accuracy did not improve from 0.73687
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9491 - loss: 0.1429 - val_accuracy: 0.7316 - val_loss: 0.5325
# Epoch 57/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9516 - loss: 0.1433
# Epoch 57: val_accuracy did not improve from 0.73687
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9504 - loss: 0.1420 - val_accuracy: 0.7267 - val_loss: 0.5442
# Epoch 58/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9505 - loss: 0.1426
# Epoch 58: val_accuracy did not improve from 0.73687
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9495 - loss: 0.1433 - val_accuracy: 0.7317 - val_loss: 0.5287
# Epoch 59/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9505 - loss: 0.1410
# Epoch 59: val_accuracy did not improve from 0.73687
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9503 - loss: 0.1434 - val_accuracy: 0.7320 - val_loss: 0.5504
# Epoch 60/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9511 - loss: 0.1415
# Epoch 60: val_accuracy did not improve from 0.73687
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9504 - loss: 0.1428 - val_accuracy: 0.7364 - val_loss: 0.5384
# Epoch 61/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9496 - loss: 0.1405
# Epoch 61: val_accuracy did not improve from 0.73687
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9501 - loss: 0.1389 - val_accuracy: 0.7278 - val_loss: 0.5346
# Epoch 62/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9486 - loss: 0.1450
# Epoch 62: val_accuracy did not improve from 0.73687
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9491 - loss: 0.1443 - val_accuracy: 0.7369 - val_loss: 0.5279
# Epoch 63/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9488 - loss: 0.1423
# Epoch 63: val_accuracy did not improve from 0.73687
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9488 - loss: 0.1427 - val_accuracy: 0.7194 - val_loss: 0.5371
# Epoch 64/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9500 - loss: 0.1400
# Epoch 64: val_accuracy did not improve from 0.73687
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9514 - loss: 0.1385 - val_accuracy: 0.7287 - val_loss: 0.5830
# Epoch 65/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9502 - loss: 0.1419
# Epoch 65: val_accuracy improved from 0.73687 to 0.73891, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9509 - loss: 0.1405 - val_accuracy: 0.7389 - val_loss: 0.5295
# Epoch 66/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9503 - loss: 0.1424
# Epoch 66: val_accuracy did not improve from 0.73891
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9500 - loss: 0.1413 - val_accuracy: 0.7198 - val_loss: 0.5379
# Epoch 67/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9510 - loss: 0.1423
# Epoch 67: val_accuracy did not improve from 0.73891
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9497 - loss: 0.1424 - val_accuracy: 0.7337 - val_loss: 0.5326
# Epoch 68/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9512 - loss: 0.1399
# Epoch 68: val_accuracy did not improve from 0.73891
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9504 - loss: 0.1412 - val_accuracy: 0.7339 - val_loss: 0.5404
# Epoch 69/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9516 - loss: 0.1393
# Epoch 69: val_accuracy improved from 0.73891 to 0.73937, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9506 - loss: 0.1419 - val_accuracy: 0.7394 - val_loss: 0.5229
# Epoch 70/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9511 - loss: 0.1387
# Epoch 70: val_accuracy did not improve from 0.73937
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9505 - loss: 0.1390 - val_accuracy: 0.7320 - val_loss: 0.5298
# Epoch 71/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9493 - loss: 0.1432
# Epoch 71: val_accuracy improved from 0.73937 to 0.74172, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9505 - loss: 0.1419 - val_accuracy: 0.7417 - val_loss: 0.5373
# Epoch 72/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9498 - loss: 0.1429
# Epoch 72: val_accuracy improved from 0.74172 to 0.74359, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9510 - loss: 0.1398 - val_accuracy: 0.7436 - val_loss: 0.5293
# Epoch 73/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9512 - loss: 0.1379
# Epoch 73: val_accuracy did not improve from 0.74359
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9519 - loss: 0.1371 - val_accuracy: 0.7400 - val_loss: 0.5314
# Epoch 74/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9534 - loss: 0.1345
# Epoch 74: val_accuracy improved from 0.74359 to 0.74516, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9520 - loss: 0.1364 - val_accuracy: 0.7452 - val_loss: 0.5347
# Epoch 75/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9510 - loss: 0.1433
# Epoch 75: val_accuracy did not improve from 0.74516
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9511 - loss: 0.1413 - val_accuracy: 0.7403 - val_loss: 0.5169
# Epoch 76/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9513 - loss: 0.1366
# Epoch 76: val_accuracy did not improve from 0.74516
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9517 - loss: 0.1378 - val_accuracy: 0.7409 - val_loss: 0.5238
# Epoch 77/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9508 - loss: 0.1408
# Epoch 77: val_accuracy improved from 0.74516 to 0.74734, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9510 - loss: 0.1406 - val_accuracy: 0.7473 - val_loss: 0.5262
# Epoch 78/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9493 - loss: 0.1427
# Epoch 78: val_accuracy improved from 0.74734 to 0.75234, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9497 - loss: 0.1415 - val_accuracy: 0.7523 - val_loss: 0.5149
# Epoch 79/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9525 - loss: 0.1377
# Epoch 79: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9521 - loss: 0.1379 - val_accuracy: 0.7333 - val_loss: 0.5198
# Epoch 80/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9519 - loss: 0.1354
# Epoch 80: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9516 - loss: 0.1361 - val_accuracy: 0.7383 - val_loss: 0.5176
# Epoch 81/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9508 - loss: 0.1390
# Epoch 81: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9512 - loss: 0.1389 - val_accuracy: 0.7384 - val_loss: 0.5286
# Epoch 82/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9523 - loss: 0.1397
# Epoch 82: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9515 - loss: 0.1401 - val_accuracy: 0.7370 - val_loss: 0.5210
# Epoch 83/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9509 - loss: 0.1404
# Epoch 83: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9505 - loss: 0.1411 - val_accuracy: 0.7378 - val_loss: 0.5203
# Epoch 84/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9504 - loss: 0.1419
# Epoch 84: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9501 - loss: 0.1425 - val_accuracy: 0.7391 - val_loss: 0.5242
# Epoch 85/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9526 - loss: 0.1348
# Epoch 85: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9517 - loss: 0.1376 - val_accuracy: 0.7436 - val_loss: 0.5117
# Epoch 86/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9531 - loss: 0.1369
# Epoch 86: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9516 - loss: 0.1398 - val_accuracy: 0.7492 - val_loss: 0.5234
# Epoch 87/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9538 - loss: 0.1341
# Epoch 87: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9522 - loss: 0.1369 - val_accuracy: 0.7320 - val_loss: 0.5316
# Epoch 88/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9516 - loss: 0.1389
# Epoch 88: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9512 - loss: 0.1395 - val_accuracy: 0.7342 - val_loss: 0.5269
# Epoch 89/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9529 - loss: 0.1363
# Epoch 89: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9522 - loss: 0.1376 - val_accuracy: 0.7478 - val_loss: 0.5190
# Epoch 90/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9496 - loss: 0.1423
# Epoch 90: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9511 - loss: 0.1394 - val_accuracy: 0.7269 - val_loss: 0.5307
# Epoch 91/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9516 - loss: 0.1408
# Epoch 91: val_accuracy did not improve from 0.75234
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9522 - loss: 0.1382 - val_accuracy: 0.7427 - val_loss: 0.5173
# Epoch 92/1000
#  997/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9516 - loss: 0.1392
# Epoch 92: val_accuracy improved from 0.75234 to 0.75453, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9522 - loss: 0.1381 - val_accuracy: 0.7545 - val_loss: 0.5113
# Epoch 93/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9515 - loss: 0.1409
# Epoch 93: val_accuracy did not improve from 0.75453
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9509 - loss: 0.1414 - val_accuracy: 0.7481 - val_loss: 0.5296
# Epoch 94/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9498 - loss: 0.1404
# Epoch 94: val_accuracy did not improve from 0.75453
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9515 - loss: 0.1391 - val_accuracy: 0.7445 - val_loss: 0.5244
# Epoch 95/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9524 - loss: 0.1368
# Epoch 95: val_accuracy did not improve from 0.75453
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9527 - loss: 0.1367 - val_accuracy: 0.7470 - val_loss: 0.5253
# Epoch 96/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9486 - loss: 0.1442
# Epoch 96: val_accuracy did not improve from 0.75453
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9493 - loss: 0.1407 - val_accuracy: 0.7366 - val_loss: 0.5242
# Epoch 97/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9526 - loss: 0.1364
# Epoch 97: val_accuracy did not improve from 0.75453
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9526 - loss: 0.1375 - val_accuracy: 0.7539 - val_loss: 0.5075
# Epoch 98/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9519 - loss: 0.1350
# Epoch 98: val_accuracy did not improve from 0.75453
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9515 - loss: 0.1362 - val_accuracy: 0.7381 - val_loss: 0.5201
# Epoch 99/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9498 - loss: 0.1409
# Epoch 99: val_accuracy did not improve from 0.75453
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9500 - loss: 0.1414 - val_accuracy: 0.7420 - val_loss: 0.5270
# Epoch 100/1000
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9534 - loss: 0.1333
# Epoch 100: val_accuracy improved from 0.75453 to 0.75609, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9515 - loss: 0.1380 - val_accuracy: 0.7561 - val_loss: 0.5268
# Epoch 101/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9516 - loss: 0.1378
# Epoch 101: val_accuracy did not improve from 0.75609
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9531 - loss: 0.1353 - val_accuracy: 0.7508 - val_loss: 0.5533
# Epoch 102/1000
#  999/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9514 - loss: 0.1397
# Epoch 102: val_accuracy did not improve from 0.75609
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9512 - loss: 0.1382 - val_accuracy: 0.7561 - val_loss: 0.5110
# Epoch 103/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9521 - loss: 0.1382
# Epoch 103: val_accuracy improved from 0.75609 to 0.75656, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9514 - loss: 0.1384 - val_accuracy: 0.7566 - val_loss: 0.5590
# Epoch 104/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9525 - loss: 0.1350
# Epoch 104: val_accuracy improved from 0.75656 to 0.76578, saving model to best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9526 - loss: 0.1368 - val_accuracy: 0.7658 - val_loss: 0.5362
# Epoch 105/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9532 - loss: 0.1383
# Epoch 105: val_accuracy did not improve from 0.76578
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9526 - loss: 0.1379 - val_accuracy: 0.7423 - val_loss: 0.5092
# Epoch 106/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9526 - loss: 0.1342
# Epoch 106: val_accuracy did not improve from 0.76578
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9520 - loss: 0.1378 - val_accuracy: 0.7331 - val_loss: 0.5177
# Epoch 107/1000
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9525 - loss: 0.1374
# Epoch 107: val_accuracy did not improve from 0.76578
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9536 - loss: 0.1352 - val_accuracy: 0.7447 - val_loss: 0.5229
# Epoch 108/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9528 - loss: 0.1359
# Epoch 108: val_accuracy did not improve from 0.76578
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9526 - loss: 0.1359 - val_accuracy: 0.7491 - val_loss: 0.5197
# Epoch 109/1000
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9532 - loss: 0.1345
# Epoch 109: val_accuracy did not improve from 0.76578
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.9546 - loss: 0.1332 - val_accuracy: 0.7470 - val_loss: 0.5051
# Epoch 171: early stopping
# Restoring model weights from the end of the best epoch: 121.

# %%
from plotting import plot_model_history, make_roc
plot_model_history(results)
plt.title("ReLU Model")
# Out:
# Text(0.5, 1.0, 'ReLU Model')

# %%
# stat calculation taken from original code

def decay(x, p_logical, x0):
  """ This functions is used to make a exponential fit to the fidelity
      curves """
  return (1 + (1 - 2 * p_logical)**(x - x0)) / 2.

def calc_stats(data, n_sampling=5000, x0_max=10, verbose=False):
    """ calculates the logical error rate and error bars """

    # since it is possible that the batch does not contain fidelities
    # for all steps, hence we need a list with all steps for which
    # predictions excist (we call it 'steps')
    steps, data_nonzero = [], []
    fids, rs_means_l, plogs_bs = [], [], []

    # in the following we assume that the first step is s = 1
    for s in range(1, len(data) + 1):
        dat = data[s - 1]
        if len(dat) != 0:
            # non-trivial data points
            steps.append(s)
            data_nonzero.append(dat)
            # fidelities
            fids.append(np.mean(dat))

    # fit decay curve to the non-tivial data
    popt, pcov = optim.curve_fit(
        decay, steps, fids, bounds=((0.0001, 0.0001), (.1, x0_max)))
    plog, x0 = popt[0], popt[1]
    if x0 > 0.99 * x0_max:
        print("WARNING, x0 is larger than", x0_max,
            "the fitting algorithm fails")
    if plog > .09:
        print("WARNING, plog is larger than 9%, the fitting algorithm fails")



    res_dict = {'steps': steps, 'fids': fids, 'plog': plog, 'x0': x0, 'plog_error': np.sqrt(pcov[0,0])}
    if verbose:
        print("logical error rate:", round(plog * 100, 5), "%")
        print("x0 offset", round(x0, 3))

    return res_dict

# %%
num_samples = int(10000)


batch = None
for gen in data.gen_batches(num_samples, 1, data_type='test'):
    batch = gen
x1, x2, fx, l1, _, y_actual = batch
y_prob = model.predict((x1,x2,fx))
# Out:
# 7188/7188 ━━━━━━━━━━━━━━━━━━━━ 171s 24ms/step

# %% [markdown]
# # Figure 3

# %%
y_preds_bool = np.empty_like(y_actual)
l_arr = np.array(range(501))
errors = np.zeros_like(l_arr)
samples = np.zeros_like(l_arr)
for idx in range(y_actual.size):
    samples[l1[idx]] += 1
    y_pred = y_prob[idx] > 0.5
    y_preds_bool[idx] = y_pred
    if (y_pred != y_actual[idx]) :
        errors[l1[idx]] += 1

comp_list = np.equal(y_preds_bool, y_actual).astype('float')
comparison = []
for n in range(max(l1)):
    comparison.append([])
for n in range(len(comp_list)):
    idx = l1[n] - 1
    comparison[idx].append(comp_list[n])
stats_dict = calc_stats(comparison, n_sampling=5000, x0_max=10, verbose=True)
fidelity = np.divide(samples - errors, samples, out=np.zeros_like(errors, dtype=float), where=(samples != 0)).astype(float)

x, y, yerr = [], [], []
for idx in range(len(fidelity)):
    if (fidelity[idx] != 0):
        x.append(l_arr[idx])
        y.append(fidelity[idx])

        # binomial error calculation (bootstraps 3sigma)
        se = np.sqrt(fidelity[idx] * (1 - fidelity[idx]) / samples[idx])
        yerr.append(se)


plog = stats_dict['plog']
x0 = stats_dict['x0']

t = np.linspace(5, 300, 10000)
F = (1 + (1 - 2 * plog)**(t - x0)) / 2

plt.errorbar(x, y, yerr=yerr, fmt='o', capsize=3, label='Data', markersize=2.5)
plt.title("Fidelity vs Number of Cycles")
plt.plot(t, F, linestyle = "-", label = f"ϵ = {round(plog*100, 4)}%")

plt.legend()
plt.ylabel(r"Logical Fidelity $\mathcal{F}$")
plt.xlabel("Cycles of Stabilizer Measurement (t)")
plt.grid(0)
plt.savefig(f"Figure3_N={num_samples}ReLu.png", dpi=300)
plt.show()

print(f"Overall Accuracy: {1 - np.sum(errors) / np.sum(samples)}")
# Out:
# logical error rate: 0.39815 %
# x0 offset 3.722
# Overall Accuracy: 0.7771347826086956

# %% [markdown]
# '# Figure 4 Data

# %%
Figure4_lst = []
Figure4_error_lst =[]
fy_lst = [0, 0.5, 1, 1.5, 2]

for fy in fy_lst:
    test_fname = f"surf17fy{fy}_test.db"



    batch = None
    for gen in data.gen_batches(num_samples, 1, data_type='test'):
        batch = gen
    x1, x2, fx, l1, _, y_actual = batch
    y_prob = model.predict((x1,x2,fx))

    print(f"fy = {fy}")

    y_preds_bool = np.empty_like(y_actual)
    l_arr = np.array(range(501))
    errors = np.zeros_like(l_arr)
    samples = np.zeros_like(l_arr)
    for idx in range(y_actual.size):
        samples[l1[idx]] += 1
        y_pred = y_prob[idx] > 0.5
        y_preds_bool[idx] = y_pred
        if (y_pred != y_actual[idx]) :
            errors[l1[idx]] += 1

    comp_list = np.equal(y_preds_bool, y_actual).astype('float')
    comparison = []
    for n in range(max(l1)):
        comparison.append([])
    for n in range(len(comp_list)):
        idx = l1[n] - 1
        comparison[idx].append(comp_list[n])
    stats_dict = calc_stats(comparison, n_sampling=5000, x0_max=10, verbose=True)

    Figure4_lst.append(stats_dict['plog'])
    Figure4_error_lst.append(stats_dict['plog_error'])

print(Figure4_lst)
# Out:
# 7188/7188 ━━━━━━━━━━━━━━━━━━━━ 171s 24ms/step
# fy = 0
# logical error rate: 0.38563 %
# x0 offset 3.47
# 7188/7188 ━━━━━━━━━━━━━━━━━━━━ 173s 24ms/step
# fy = 0.5
# logical error rate: 0.3878 %
# x0 offset 2.355
# 7188/7188 ━━━━━━━━━━━━━━━━━━━━ 169s 24ms/step
# fy = 1
# logical error rate: 0.3936 %
# x0 offset 3.003
# 7188/7188 ━━━━━━━━━━━━━━━━━━━━ 170s 24ms/step
# fy = 1.5
# logical error rate: 0.38737 %
# x0 offset 4.003
# 7188/7188 ━━━━━━━━━━━━━━━━━━━━ 171s 24ms/step
# fy = 2
# logical error rate: 0.39895 %
# x0 offset 4.085
# [0.0038562939373153653, 0.0038780262008848492, 0.003935957541843276, 0.0038736879456758183, 0.0039894646641140145]

# %%
Figure4_lst_p = np.array(Figure4_lst)*100
Figure4_error_lst_p = np.array(Figure4_error_lst)*100

plt.errorbar(fy_lst, Figure4_lst_p, yerr=Figure4_error_lst_p, fmt='.', capsize=5, capthick=2)
plt.xlabel("Ratio of y Error Rate to x, z Error Rate")
plt.ylabel("Logical Error Rate per Cycle [%]")
plt.ylim(0, 0.5)
plt.savefig(f"Figure4_N={num_samples}ReLu.png", dpi=300)
plt.show()
