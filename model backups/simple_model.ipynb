# %%
from database_io import *
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.utils import Sequence
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# path of databases (must exist)
db_path = "db/"

# filenames of databases (this must be sqlite3 databases)
train_fname = "surf17_train.db"
validation_fname = "surf17_validation.db"
test_fname = "surf17_test.db"

dim_syndr = 8
dim_fsyndr = 4
n_steps_net1 = 20
n_steps_net2 = 3

data = DatabaseIO(dim_syndr, dim_fsyndr, n_steps_net1, n_steps_net2)

# %%
try:
    data.close_databases()
except:
    pass
data.load_data(db_path + train_fname, db_path + validation_fname, db_path + test_fname)



batch_size = 64
n_batches_train = 5000
n_batches_validation = 10



class DecoderSequence(Sequence):
    def __init__(self, data, batch_size, n_batches, data_type):
        self.data = data
        self.batch_size = batch_size
        self.n_batches = n_batches
        self.data_type = data_type
        self.on_epoch_end()

    def __len__(self):
        return self.n_batches

    def __getitem__(self, idx):
        # return the idx-th batch captured at epoch start
        return self.epoch_batches[idx]

    def on_epoch_end(self):
        """Called automatically by Keras at the end of each epoch."""
        gen = self.data.gen_batches(
            self.batch_size,
            self.n_batches,
            data_type=self.data_type
        )

        self.epoch_batches = []
        for _ in range(self.n_batches):
            batch_x1, batch_x2, batch_fx, batch_l1, batch_l2, batch_y = next(gen)

            # Wrap into Keras multi-input format
            inputs = (batch_x1, batch_x2, batch_fx, batch_l1) #, batch_l1, batch_l2)
            outputs = batch_y
            self.epoch_batches.append((inputs, outputs))

train_seq = DecoderSequence(
    data,
    batch_size=batch_size,
    n_batches=n_batches_train,
    data_type='training'
)

val_seq = DecoderSequence(
    data,
    batch_size=batch_size,
    n_batches=n_batches_validation,
    data_type='validation'
)
# Out:
# loaded databases and checked exclusiveness training, validation, and test keys
# N_training=400000, N_validaiton=1000, N_test=5000.

# %%
x1 = Input(shape=(None, dim_syndr), name="x1_full")
x2 = Input(shape=(n_steps_net2, dim_syndr), name="x2_recent")
fx = Input(shape=(dim_fsyndr,), name="final_increment")

l1_input = Input(shape=(), dtype=tf.int32, name="seq_len")

x1_masked = layers.Masking(mask_value=0.0)(x1)



mask_layer = layers.Lambda(lambda x: tf.sequence_mask(x[1], maxlen=tf.shape(x[0])[1]), output_shape=(None,))([x1, l1_input])

# ---- Network 1 ---- (full syndrome history)
h1 = layers.LSTM(64, return_sequences=True, kernel_regularizer=keras.regularizers.l2(1e-5))(x1_masked)
# h1 = layers.LSTM(64, return_sequences=True)(x1_masked)
h1 = layers.Dropout(0.2)(h1)
h1 = layers.LSTM(64, kernel_regularizer=keras.regularizers.l2(1e-5))(h1)
h1 = layers.Dropout(0.2)(h1)
p1 = layers.Dense(64, activation="relu", name="p1", kernel_regularizer=keras.regularizers.l2(1e-5))(h1)
p1 = layers.Dropout(0.2)(p1)
p1 = layers.Dense(1, activation="sigmoid", kernel_regularizer=keras.regularizers.l2(1e-5), name="p1_prob")(p1)

# ---- Network 2 ---- (recent syndrome + final increment)
h2 = layers.LSTM(64, kernel_regularizer=keras.regularizers.l2(1e-5), return_sequences=True)(x2)
h2 = layers.Dropout(0.2)(h2)
h2 = layers.LSTM(64, kernel_regularizer=keras.regularizers.l2(1e-5))(h2)
h2 = layers.Dropout(0.2)(h2)

h2_aug = layers.Concatenate()([h2, fx])

p2 = layers.Dense(64, activation="relu", name="p2", kernel_regularizer=keras.regularizers.l2(1e-5))(h2_aug)
p2 = layers.Dropout(0.2)(p2)
p2 = layers.Dense(1, activation="sigmoid", name="p2_prob", kernel_regularizer=keras.regularizers.l2(1e-5))(p2)

# ---- Final combination p = probabilistic sum ---- #
p_final = layers.Lambda(lambda x: x[0]*(1-x[1]) + x[1]*(1-x[0]))([p1, p2])

model = Model(inputs=[x1, x2, fx, l1_input], outputs=p_final)
model.summary()

model.compile(
    loss="binary_crossentropy",
    optimizer=tf.keras.optimizers.Adam(1e-3),
    metrics=["accuracy"]
)


num_epochs = 1000

checkpoint = ModelCheckpoint(
    'best_model.keras',       # file path to save the model
    monitor='val_accuracy',    # metric to monitor
    verbose=1,             # prints message when saving
    save_best_only=True,   # only save if improved
    mode='max'             # 'min' for loss, 'max' for accuracy
)

results = model.fit(
    train_seq,
    steps_per_epoch=n_batches_train,
    epochs=num_epochs,
    verbose=1,
    validation_data=val_seq,
    validation_steps=n_batches_validation,
    callbacks=[checkpoint]
)
# Out:
# WARNING:tensorflow:From c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ x1_full             │ (None, None, 8)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, None, 8)   │          0 │ x1_full[0][0]     │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ x2_recent           │ (None, 3, 8)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking (Masking)   │ (None, None, 8)   │          0 │ x1_full[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any (Any)           │ (None, None)      │          0 │ not_equal[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 3, 64)     │     18,688 │ x2_recent[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, None, 64)  │     18,688 │ masking[0][0],    │
# │                     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 3, 64)     │          0 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, None, 64)  │          0 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 64)        │     33,024 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 64)        │     33,024 │ dropout[0][0],    │
# │                     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 64)        │          0 │ lstm_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_increment     │ (None, 4)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ lstm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 68)        │          0 │ dropout_4[0][0],  │
# │ (Concatenate)       │                   │            │ final_increment[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p1 (Dense)          │ (None, 64)        │      4,160 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p2 (Dense)          │ (None, 64)        │      4,416 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64)        │          0 │ p1[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64)        │          0 │ p2[0][0]          │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p1_prob (Dense)     │ (None, 1)         │         65 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p2_prob (Dense)     │ (None, 1)         │         65 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ seq_len             │ (None)            │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 1)         │          0 │ p1_prob[0][0],    │
# │                     │                   │            │ p2_prob[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 112,130 (438.01 KB)
#  Trainable params: 112,130 (438.01 KB)
#  Non-trainable params: 0 (0.00 B)
# c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7789 - loss: 0.3999
# Epoch 1: val_accuracy improved from None to 0.61719, saving model to best_model.keras
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 121s 23ms/step - accuracy: 0.8635 - loss: 0.2834 - val_accuracy: 0.6172 - val_loss: 0.6096
# Epoch 2/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9189 - loss: 0.1959
# Epoch 2: val_accuracy improved from 0.61719 to 0.64688, saving model to best_model.keras
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 111s 22ms/step - accuracy: 0.9226 - loss: 0.1900 - val_accuracy: 0.6469 - val_loss: 0.6164
# Epoch 3/1000
# 4998/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9321 - loss: 0.1754
# Epoch 3: val_accuracy improved from 0.64688 to 0.71719, saving model to best_model.keras
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 121s 24ms/step - accuracy: 0.9343 - loss: 0.1714 - val_accuracy: 0.7172 - val_loss: 0.5681
# Epoch 4/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9407 - loss: 0.1635
# Epoch 4: val_accuracy did not improve from 0.71719
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 116s 23ms/step - accuracy: 0.9416 - loss: 0.1614 - val_accuracy: 0.7078 - val_loss: 0.5573
# Epoch 5/1000
# 4998/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9440 - loss: 0.1579
# Epoch 5: val_accuracy did not improve from 0.71719
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 110s 22ms/step - accuracy: 0.9444 - loss: 0.1562 - val_accuracy: 0.6922 - val_loss: 0.5657
# Epoch 6/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9465 - loss: 0.1527
# Epoch 6: val_accuracy improved from 0.71719 to 0.73281, saving model to best_model.keras
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 122s 24ms/step - accuracy: 0.9472 - loss: 0.1517 - val_accuracy: 0.7328 - val_loss: 0.5181
# Epoch 7/1000
# 4998/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9488 - loss: 0.1494
# Epoch 7: val_accuracy improved from 0.73281 to 0.73906, saving model to best_model.keras
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 138s 28ms/step - accuracy: 0.9488 - loss: 0.1491 - val_accuracy: 0.7391 - val_loss: 0.5083
# Epoch 8/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9499 - loss: 0.1453
# Epoch 8: val_accuracy improved from 0.73906 to 0.74844, saving model to best_model.keras
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 138s 28ms/step - accuracy: 0.9499 - loss: 0.1457 - val_accuracy: 0.7484 - val_loss: 0.5105
# Epoch 9/1000
# 4998/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9517 - loss: 0.1433
# Epoch 9: val_accuracy improved from 0.74844 to 0.76094, saving model to best_model.keras
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 139s 28ms/step - accuracy: 0.9511 - loss: 0.1435 - val_accuracy: 0.7609 - val_loss: 0.5124
# Epoch 10/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9518 - loss: 0.1411
# Epoch 10: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 140s 28ms/step - accuracy: 0.9516 - loss: 0.1417 - val_accuracy: 0.7281 - val_loss: 0.5111
# Epoch 11/1000
# 4998/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9518 - loss: 0.1422
# Epoch 11: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 138s 28ms/step - accuracy: 0.9519 - loss: 0.1415 - val_accuracy: 0.7391 - val_loss: 0.5162
# Epoch 12/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9524 - loss: 0.1399
# Epoch 12: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 112s 22ms/step - accuracy: 0.9522 - loss: 0.1406 - val_accuracy: 0.7172 - val_loss: 0.5550
# Epoch 13/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9530 - loss: 0.1385
# Epoch 13: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 113s 23ms/step - accuracy: 0.9527 - loss: 0.1393 - val_accuracy: 0.7453 - val_loss: 0.5131
# Epoch 14/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9537 - loss: 0.1359
# Epoch 14: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 120s 24ms/step - accuracy: 0.9534 - loss: 0.1373 - val_accuracy: 0.7531 - val_loss: 0.5062
# Epoch 15/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9543 - loss: 0.1351
# Epoch 15: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 114s 23ms/step - accuracy: 0.9540 - loss: 0.1367 - val_accuracy: 0.7484 - val_loss: 0.5294
# Epoch 16/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9541 - loss: 0.1350
# Epoch 16: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 113s 23ms/step - accuracy: 0.9538 - loss: 0.1362 - val_accuracy: 0.7547 - val_loss: 0.4996
# Epoch 17/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9542 - loss: 0.1352
# Epoch 17: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 124s 25ms/step - accuracy: 0.9539 - loss: 0.1359 - val_accuracy: 0.7359 - val_loss: 0.5348
# Epoch 18/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9541 - loss: 0.1334
# Epoch 18: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 140s 28ms/step - accuracy: 0.9542 - loss: 0.1342 - val_accuracy: 0.7609 - val_loss: 0.4943
# Epoch 19/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9552 - loss: 0.1330
# Epoch 19: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 142s 28ms/step - accuracy: 0.9551 - loss: 0.1331 - val_accuracy: 0.7375 - val_loss: 0.5860
# Epoch 20/1000
# 4998/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9550 - loss: 0.1319
# Epoch 20: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 145s 29ms/step - accuracy: 0.9552 - loss: 0.1323 - val_accuracy: 0.7594 - val_loss: 0.5183
# Epoch 21/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9562 - loss: 0.1306
# Epoch 21: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 143s 29ms/step - accuracy: 0.9552 - loss: 0.1322 - val_accuracy: 0.7453 - val_loss: 0.5665
# Epoch 22/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9562 - loss: 0.1306
# Epoch 22: val_accuracy did not improve from 0.76094
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 142s 28ms/step - accuracy: 0.9556 - loss: 0.1313 - val_accuracy: 0.7531 - val_loss: 0.5519
# Epoch 23/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9561 - loss: 0.1294
# Epoch 23: val_accuracy improved from 0.76094 to 0.76250, saving model to best_model.keras
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 144s 29ms/step - accuracy: 0.9556 - loss: 0.1315 - val_accuracy: 0.7625 - val_loss: 0.5333
# Epoch 24/1000
# 4998/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9560 - loss: 0.1305
# Epoch 24: val_accuracy did not improve from 0.76250
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 143s 29ms/step - accuracy: 0.9556 - loss: 0.1313 - val_accuracy: 0.7547 - val_loss: 0.5166
# Epoch 25/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9562 - loss: 0.1294
# Epoch 25: val_accuracy did not improve from 0.76250
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 145s 29ms/step - accuracy: 0.9561 - loss: 0.1306 - val_accuracy: 0.7563 - val_loss: 0.5613
# Epoch 26/1000
# 4998/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9564 - loss: 0.1286
# Epoch 26: val_accuracy did not improve from 0.76250
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 120s 24ms/step - accuracy: 0.9560 - loss: 0.1300 - val_accuracy: 0.7312 - val_loss: 0.5626
# Epoch 27/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9567 - loss: 0.1291
# Epoch 27: val_accuracy did not improve from 0.76250
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 115s 23ms/step - accuracy: 0.9566 - loss: 0.1300 - val_accuracy: 0.7453 - val_loss: 0.5591
# Epoch 28/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9562 - loss: 0.1302
# Epoch 28: val_accuracy did not improve from 0.76250
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 130s 26ms/step - accuracy: 0.9563 - loss: 0.1297 - val_accuracy: 0.7312 - val_loss: 0.5332
# Epoch 29/1000
# 4998/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9570 - loss: 0.1286
# Epoch 29: val_accuracy did not improve from 0.76250
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 135s 27ms/step - accuracy: 0.9570 - loss: 0.1287 - val_accuracy: 0.7406 - val_loss: 0.5252
# Epoch 30/1000
# 4998/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9574 - loss: 0.1276
# Epoch 30: val_accuracy did not improve from 0.76250
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 115s 23ms/step - accuracy: 0.9568 - loss: 0.1290 - val_accuracy: 0.7391 - val_loss: 0.5790
# Epoch 31/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9571 - loss: 0.1275
# Epoch 31: val_accuracy did not improve from 0.76250
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 121s 24ms/step - accuracy: 0.9570 - loss: 0.1284 - val_accuracy: 0.7328 - val_loss: 0.5597
# Epoch 32/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9577 - loss: 0.1275
# Epoch 32: val_accuracy did not improve from 0.76250
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 144s 29ms/step - accuracy: 0.9573 - loss: 0.1281 - val_accuracy: 0.7531 - val_loss: 0.6289
# Epoch 33/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9574 - loss: 0.1269
# Epoch 33: val_accuracy improved from 0.76250 to 0.77188, saving model to best_model.keras
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 151s 30ms/step - accuracy: 0.9575 - loss: 0.1279 - val_accuracy: 0.7719 - val_loss: 0.5228
# Epoch 34/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9584 - loss: 0.1252
# Epoch 34: val_accuracy did not improve from 0.77188
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 151s 30ms/step - accuracy: 0.9579 - loss: 0.1268 - val_accuracy: 0.7391 - val_loss: 0.5333
# Epoch 35/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9579 - loss: 0.1265
# Epoch 35: val_accuracy did not improve from 0.77188
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 151s 30ms/step - accuracy: 0.9579 - loss: 0.1264 - val_accuracy: 0.7437 - val_loss: 0.5615
# Epoch 36/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9585 - loss: 0.1255
# Epoch 36: val_accuracy did not improve from 0.77188
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 152s 30ms/step - accuracy: 0.9577 - loss: 0.1266 - val_accuracy: 0.7609 - val_loss: 0.5396
# Epoch 37/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9575 - loss: 0.1259
# Epoch 37: val_accuracy did not improve from 0.77188
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 154s 31ms/step - accuracy: 0.9576 - loss: 0.1265 - val_accuracy: 0.7203 - val_loss: 0.6204
# Epoch 38/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9582 - loss: 0.1259
# Epoch 38: val_accuracy improved from 0.77188 to 0.77344, saving model to best_model.keras
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 155s 31ms/step - accuracy: 0.9578 - loss: 0.1262 - val_accuracy: 0.7734 - val_loss: 0.5830
# Epoch 39/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9582 - loss: 0.1261
# Epoch 39: val_accuracy improved from 0.77344 to 0.78438, saving model to best_model.keras
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 154s 31ms/step - accuracy: 0.9582 - loss: 0.1256 - val_accuracy: 0.7844 - val_loss: 0.5882
# Epoch 40/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9590 - loss: 0.1238
# Epoch 40: val_accuracy did not improve from 0.78438
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 155s 31ms/step - accuracy: 0.9585 - loss: 0.1252 - val_accuracy: 0.7406 - val_loss: 0.6050
# Epoch 41/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9581 - loss: 0.1252
# Epoch 41: val_accuracy did not improve from 0.78438
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 155s 31ms/step - accuracy: 0.9584 - loss: 0.1254 - val_accuracy: 0.7266 - val_loss: 0.6208
# Epoch 42/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9594 - loss: 0.1234
# Epoch 42: val_accuracy did not improve from 0.78438
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 157s 31ms/step - accuracy: 0.9591 - loss: 0.1244 - val_accuracy: 0.7172 - val_loss: 0.6617
# Epoch 43/1000
# 4998/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9592 - loss: 0.1233
# Epoch 43: val_accuracy did not improve from 0.78438
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 142s 28ms/step - accuracy: 0.9588 - loss: 0.1248 - val_accuracy: 0.7422 - val_loss: 0.6112
# Epoch 44/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9593 - loss: 0.1237
# Epoch 44: val_accuracy did not improve from 0.78438
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 123s 25ms/step - accuracy: 0.9586 - loss: 0.1250 - val_accuracy: 0.7453 - val_loss: 0.6920
# Epoch 45/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9589 - loss: 0.1243
# Epoch 45: val_accuracy did not improve from 0.78438
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 136s 27ms/step - accuracy: 0.9586 - loss: 0.1251 - val_accuracy: 0.7312 - val_loss: 0.6521
# Epoch 46/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9595 - loss: 0.1226
# Epoch 46: val_accuracy did not improve from 0.78438
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 157s 31ms/step - accuracy: 0.9589 - loss: 0.1243 - val_accuracy: 0.7266 - val_loss: 0.6183
# Epoch 47/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9589 - loss: 0.1242
# Epoch 47: val_accuracy did not improve from 0.78438
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 158s 32ms/step - accuracy: 0.9586 - loss: 0.1245 - val_accuracy: 0.7453 - val_loss: 0.7278
# Epoch 48/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9596 - loss: 0.1229
# Epoch 48: val_accuracy did not improve from 0.78438
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 161s 32ms/step - accuracy: 0.9592 - loss: 0.1235 - val_accuracy: 0.7500 - val_loss: 0.6877
# Epoch 49/1000
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9595 - loss: 0.1227
# Epoch 49: val_accuracy did not improve from 0.78438
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 161s 32ms/step - accuracy: 0.9595 - loss: 0.1228 - val_accuracy: 0.7516 - val_loss: 0.6926
# Epoch 50/1000
# 4999/5000 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9597 - loss: 0.1221
# Epoch 50: val_accuracy did not improve from 0.78438
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 158s 32ms/step - accuracy: 0.9593 - loss: 0.1236 - val_accuracy: 0.7453 - val_loss: 0.6783
# Epoch 51/1000
# 2110/5000 ━━━━━━━━━━━━━━━━━━━━ 1:17 27ms/step - accuracy: 0.9603 - loss: 0.1215
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 58
#      48 num_epochs = 1000
#      50 checkpoint = ModelCheckpoint(
#      51     'best_model.keras',       # file path to save the model
#      52     monitor='val_accuracy',    # metric to monitor
#    (...)     55     mode='max'             # 'min' for loss, 'max' for accuracy
#      56 )
# ---> 58 results = model.fit(
#      59     train_seq,
#      60     steps_per_epoch=n_batches_train,
#      61     epochs=num_epochs,
#      62     verbose=1,
#      63     validation_data=val_seq,
#      64     validation_steps=n_batches_validation,
#      65     callbacks=[checkpoint]
#      66 )
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:377, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375 for begin_step, end_step, iterator in epoch_iterator:
#     376     callbacks.on_train_batch_begin(begin_step)
# --> 377     logs = self.train_function(iterator)
#     378     callbacks.on_train_batch_end(end_step, logs)
#     379     if self.stop_training:
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:220, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     216 def function(iterator):
#     217     if isinstance(
#     218         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219     ):
# --> 220         opt_outputs = multi_step_on_iterator(iterator)
#     221         if not opt_outputs.has_value():
#     222             raise StopIteration
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
num_samples = 500
for batch in data.gen_batches(num_samples, 1, data_type='validation'):
    errors = 0
    x1, x2, fx, l1, _, y_actual = batch
    y_prob = model.predict((x1,x2,fx,l1))
    for idx in range(y_actual.size):
        y_pred = y_prob[idx] < 0.5
        # print(f"Predicted Probability: {y_prob[idx]}  Prediction: {y_pred}  Actual: {y_actual[idx]}")
        if (y_pred != y_actual[idx]) :
            errors += 1
print(f"Accuracy: {errors / num_samples}")
